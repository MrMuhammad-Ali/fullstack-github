# %%
cites = ['karachi', 'lahore', 'quetta', 'murre', 'larkana']

# %%
type(cites)
# Out:
# list

# %%
cites.count('karachi')
# Out:
# 1

# %%
cites.reverse()

# %%
cites.sort()

# %%
cites
# Out:
# ['karachi', 'lahore', 'larkana', 'murre', 'quetta']

# %%
fruits = ['cherry', 'mango', 'apple', 'banana', 'grapes']

# %%
fruits.sort(reverse=False)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'grapes', 'mango']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
copy_fruits = fruits.copy()
copy_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
print(fruits)
print(copy_fruits)
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
copy_fruits.append('kiwi')

# %%
copy_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'kiwi', 'kiwi']

# %%
fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
# cites = [gdkdjfhgkdfhkghhglhhf]
# another_cites = cities

# %%
another_fruits = fruits

# %%
another_fruits.append('pear')

# %%
another_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'pear', 'pear']

# %%
fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'pear', 'pear']

# %%
print(id(fruits))
print(id(another_fruits))
print(id(copy_fruits))
# Out:
# 2332639138816
# 2332639138816
# 2332644849216

# %% [markdown]
# # Split and join (string remaining methods)

# %%
email = 'aliabro@gmail.com'

# %%
print(email.split('@'))
print(email.split('@')[0])
# Out:
# ['aliabro', 'gmail.com']
# aliabro

# %%
print(email.split('@'))
print(email.split('@')[1])
# Out:
# ['aliabro', 'gmail.com']
# gmail.com

# %%
info = 'alikhan-python-smit-karachi'

# %%
split_list = info.split('-')

# %%
split_list
# Out:
# ['alikhan', 'python', 'smit', 'karachi']

# %%
'_'.join(split_list)
# Out:
# 'alikhan_python_smit_karachi'

# %%
lst = list()

# %%
lst
# Out:
# []

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
lst = [3, 5, 25, 1, 3]
max(lst)
min(lst)
# Out:
# 1

# %%
name = ['Amir', 'Bear', 'Charlton', 'Daman']
print(name[-1][-3])
# Out:
# m

# %%
[1, 3, 2]*2
# Out:
# [1, 3, 2, 1, 3, 2]

# %%
list1 = [11, 2, 2]
list2 = [11, 2, 45]
print(list1 < list2)
# Out:
# True
