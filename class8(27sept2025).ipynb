# %%
fullname = 'ali khan'

# %%
#.count hamen btata hai k ali kitni bar aya hai yn a kitni bar aya hai wo count kar kay btata hai 
fullname.count('ali')
# Out:
# 1

# %%
fullname.count('a')
# Out:
# 2

# %%
info = 'my name is ali abro i live in lahore and lahore is a beautiful city and i dont want to leave lahore'

# %%
info.count('lahore')
# Out:
# 3

# %%
start = info.find('i live')

# %%
end = info.find('city')+ len('city') -1

# %%
info.count('city')
# Out:
# 1

# %% [markdown]
# # String Slicing

# %%
# info[start: end+1] ----> start=inclusive, end = exclusive(you need to add 1)
sliced_info = info[start : end +1]
sliced_info
# Out:
# 'i live in lahore and lahore is a beautiful cit'

# %%
info
# Out:
# 'my name is ali abro i live in lahore and lahore is a beautiful city and i dont want to leave lahore'

# %% [markdown]
# #List

# %%
all_name = ['muhammad ali', 'shahzaib', 'junaid', 'qutub', 'saifullah']

# %%
type(all_name)
# Out:
# list

# %%
len(all_name)
# Out:
# 5

# %%
# How to access a single value from a list

# %%
all_name[0]
# Out:
# 'muhammad ali'

# %%
all_name[4]
# Out:
# 'saifullah'

# %% [markdown]
# #Slicing List

# %%
all_name[0:3]
# Out:
# ['muhammad ali', 'shahzaib', 'junaid']

# %%
all_name[1:4]
# Out:
# ['shahzaib', 'junaid', 'qutub']

# %%
# all_name[start: end + 1 : step]
all_name[0:5:4]
# Out:
# ['muhammad ali', 'saifullah']

# %%
all_name[0: 5 : 2]
# Out:
# ['muhammad ali', 'junaid', 'saifullah']

# %%
all_name[-4: -1]
# Out:
# ['shahzaib', 'junaid', 'qutub']

# %%
all_name[-1]
# Out:
# 'saifullah'

# %%
['muhammad ali', 'shahzaib', 'junaid']
sliced_list = all_name[0:3]
sliced_list[::-1]
# Out:
# ['junaid', 'shahzaib', 'muhammad ali']

# %%
all_name[::-1]
# Out:
# ['saifullah', 'qutub', 'junaid', 'shahzaib', 'muhammad ali']

# %%
info[::-1]
# Out:
# 'erohal evael ot tnaw tnod i dna ytic lufituaeb a si erohal dna erohal ni evil i orba ila si eman ym'

# %%
value = input('Enter anything but it will be limited to 6 charcters')[0:7]

# %%
value
# Out:
# 'pakista'

# %%
#.append kese bhe chez ko list main add karvata hai 
all_name.append('kaleem')

# %%
all_name.append('fakhar', amir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 all_name.append('fakhar', amir)
#
# NameError: name 'amir' is not defined

# %%
all_name
# Out:
# ['muhammad ali',
#  'shahzaib',
#  'junaid',
#  'qutub',
#  'saifullah',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'kaleem']

# %%
all_name
# Out:
# ['muhammad ali',
#  'shahzaib',
#  'junaid',
#  'qutub',
#  'saifullah',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'kaleem']

# %%
all_name.append('amjad')

# %%
all_name
# Out:
# ['muhammad ali',
#  'shahzaib',
#  'junaid',
#  'qutub',
#  'saifullah',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'amjad',
#  'amjad']

# %%
cric = input('Enter any cricketers')

# %%
cric
# Out:
# 'Amir'

# %%
all_name.append(cric)

# %%
all_name
# Out:
# ['muhammad ali',
#  'shahzaib',
#  'junaid',
#  'qutub',
#  'saifullah',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'kaleem',
#  'amjad',
#  'amjad',
#  'Amir',
#  'Amir']
