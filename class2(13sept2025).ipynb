# %%
print('helo world')
print('this is our first class')
# Out:
# helo world
# this is our first class

# %%
print('fakhar bobzi rizwan')
# Out:
# fakhar bobzi rizwan

# %%
print('fakhar-----bobzi----rizwan')
print('akhar bobzi rizwan', sep='\n')
# Out:
# fakhar-----bobzi----rizwan
# akhar bobzi rizwan

# %%
print('this is our first line \nThis is our second line')
# Out:
# this is our first line
# This is our second line

# %%
print(4+2)
print(4-2)
print(4*2)
print(4/2)
# Out:
# 6
# 2
# 8
# 2.0

# %%
print(23.3+2)
print(2+3)
print(2+3)
# Out:
# 25.3
# 5
# 5

# %%
print('2+3')
print(2+3)
# Out:
# 2+3
# 5

# %%
# Types of Deta (Data Types
# String--Text
# Integar--Whole Number
# Floating point data-- Decemal Number
# Boolen--True and False

# %%
print('this is a text data')
print(234)
print(234.3)
print(True, False)
# Out:
# this is a text data
# 234
# 234.3
# True False

# %%
print(type('Muhammad Ali'))
print(type(12))
print(type(12.3))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
