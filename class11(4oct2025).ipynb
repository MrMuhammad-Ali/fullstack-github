# %% [markdown]
# # Dictionary

# %%
# info ={ 'key':'value' }
info = {'name': 'Muhammad Ali', 'course': 'python', 'age':'30' }

# %%
type(info)
# Out:
# dict

# %%
len(info)
# Out:
# 3

# %%
info
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'age': '30'}

# %%
info
data = {"virat kohli": 'off side delivery'
        "babar azam": 'Cricket',
        "Haris Rauf", 'Bowling',
        10: 'Shahid Afridi',
        [123]: 'List Value'
        }
# Out:
#   Cell In[9], line 3
#     "babar azam": 'Cricket',
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # no, a python list cannot be directly used as a key in a dictionary. Dictionary keys in python must be hashable and immutable. List are mutable, meaning their content can be change after they are ceated, and therefore they are not hashable.

# %%
info
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'age': '30'}

# %%
cites = ['karachi', 'lahore', 'murre']
cites[1] = 'Larkana'

# %%
cites
# Out:
# ['karachi', 'Larkana', 'murre']

# %%
info['city'] = 'karachi'
info
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'age': '30', 'city': 'karachi'}

# %%
info[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 info[0]
#
# KeyError: 0

# %% [markdown]
# info['name']

# %%
info['city'] = 'waseem bhai'
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'waseem bhai'}

# %%
info.update({'campus':'gulshan', 'city':'karachi'})
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'karachi',
#  'campus': 'gulshan'}

# %% [markdown]
# # How to remove a value from a dictionary

# %%
del info['campus']

# %%
info
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'age': '30', 'city': 'karachi'}

# %%
info.update({'city':'Karachi', 'campus':'gulshan', 'Topi': 'Bike kharab hogai the'})

# %%
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'Karachi',
#  'campus': 'gulshan',
#  'Topi': 'Bike kharab hogai the'}

# %%
topi =info.pop('Topi')

# %%
topi
# Out:
# 'Bike kharab hogai the'

# %%
popitem_value = info.popitem()

# %%
popitem_value
# Out:
# ('campus', 'gulshan')

# %%
info
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'age': '30', 'city': 'Karachi'}

# %%
info.items()
# Out:
# dict_items([('name', 'Muhammad Ali'), ('course', 'python'), ('age', '30'), ('city', 'Karachi')])

# %%
topi = input('Enter your topi')
reason = input('Enter your topi reason')

# %%
info[topi] = reason

# %%
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'Karachi',
#  'Topi': 'Bike kharab ho gaei the '}

# %%
list(info.keys())
# Out:
# ['name', 'course', 'age', 'city', 'Topi']

# %%
list(info.values())
# Out:
# ['Muhammad Ali', 'python', '30', 'Karachi', 'Bike kharab ho gaei the ']

# %%
old_items = list(info.items())
old_items
# Out:
# [('name', 'Muhammad Ali'),
#  ('course', 'python'),
#  ('age', '30'),
#  ('city', 'Karachi'),
#  ('Topi', 'Bike kharab ho gaei the ')]

# %%
info['name']
# Out:
# 'Muhammad Ali'

# %%
info['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 info['Name']
#
# KeyError: 'Name'

# %%
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'Karachi',
#  'Topi': 'Bike kharab ho gaei the '}

# %%
info.get('name')
# Out:
# 'Muhammad Ali'

# %%
info.get('Name')

# %%
info['Topi'] = None

# %%
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'Karachi',
#  'Topi': None}

# %%
print(info.get('topi'))
# Out:
# None

# %%
print(info.get('name'))
print(info.get('Name', 'traffic bohat the'))
print(info.get('Topi', 'traffic bohat tha'))
# Out:
# Muhammad Ali
# traffic bohat the
# None

# %%
info
# Out:
# {'name': 'Muhammad Ali',
#  'course': 'python',
#  'age': '30',
#  'city': 'Karachi',
#  'Topi': None}

# %%
info.get('Name', 'traffic bohat tha')
# Out:
# 'traffic bohat tha'

# %%
values = list(info.values())
print(values.index('Muhammad Ali'))
# Out:
# 0

# %%
keys = list(info.keys())
print(keys[0])
# print(values)
# Out:
# name

# %%
print(values)
print(f"index of Muhammad Ali in the list {values.index('Muhammad Ali')}")
print(keys)
print(f'the key of value "Muhammad Ali" is: {keys[0]}')
# Out:
# ['Muhammad Ali', 'python', '30', 'Karachi', None]
# index of Muhammad Ali in the list 0
# ['name', 'course', 'age', 'city', 'Topi']
# the key of value "Muhammad Ali" is: name

# %%
info = {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None}

# %%
info_copy = info.copy()
print(info)
print(info_copy)
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None}
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None}

# %% [markdown]
# # .pop list say object remove karta hai

# %%
info_copy.pop('Topi')

# %%
print(info)
print(info_copy)
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None}
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi'}

# %%
another_info_copy =info

# %%
another_info_copy['Testing'] = 'any value'

# %%
print(info)
print(another_info_copy)
# Out:
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None, 'Testing': 'any value'}
# {'name': 'Muhammad Ali', 'course': 'python', 'city': 'karachi', 'Topi': None, 'Testing': 'any value'}

# %%
another_info_copy is info
# Out:
# True

# %%
another_info_copy is info_copy
# Out:
# False

# %%
info.clear()

# %%
info
# Out:
# {}
