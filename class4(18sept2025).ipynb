# %%
# ipynb stands for interactive python notebook

# %%
# Basic data Types
# 1 string
# 2 Integar
# 3 Float
# 4 Boolean

# %%
fname = 'Ali'
lname = 'Abro'
print(fname, lname)
# Out:
# Ali Abro

# %%
fname
# Out:
# 'Ali'

# %%
# User Input Using Input()Function

# %%
value = input('Enter any value')

# %%
print(value)
print(type(value))
# Out:
# 5
# <class 'str'>

# %%
fname = input('enter first name:')
lname = input('enter second name:')
print(fname, lname)
# Out:
# Muhammad Ali

# %%
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
result = num1 + num2
print('This is your result' ,result)
# Out:
# This is your result 45

# %%
print(2 + 1)
print(2 + 1) #concatenation
print('+') #Concatenation
# print(2 '+' 1) This is not the right way (invalid syntax)
# Out:
# 3
# 3
# +

# %%
# Type Casting
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Type Casting
# ----> 2 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
num = int('2')
type(num)
# Out:
# int

# %%
num = '23.3'
result = float(num)
print(result, type(result))
# Out:
# 23.3 <class 'float'>

# %%
num = 23
result = str(num)
print('the value of result is' ,result, 'and the type of result is' ,type(result))
# Out:
# the value of result is 23 and the type of result is <class 'str'>

# %%
print(bool(0))
print(bool(1))
print(bool(23))
# Out:
# False
# True
# True

# %%
print(bool('kuch bhe ho sakta hai'))
print(bool(' '))
print(bool(''))
# Out:
# True
# True
# False

# %%
#String
num = 23
result = str(num)
print('the value of result is' ,result, 'and the type of result is' ,type(result))
# Out:
# the value of result is 23 and the type of result is <class 'str'>

# %%
#String Formatting
num = 23
print('the value of result is' ,num, 'and the type of result is' ,type(num))
print(f'the value of result is {num} andthe type of result is {type(num)}') #string formatting
# Out:
# the value of result is 23 and the type of result is <class 'int'>
# the value of result is 23 andthe type of result is <class 'int'>

# %%
age = 30
course = 'python'
campus = 'smit'
print(f'I am {age} years old and i study {course} in {campus} gulsion campus')
# Out:
# I am 30 years old and i study python in smit gulsion campus

# %%
print('this is first line \nThis is second line')
# Out:
# this is first line
# This is second line
