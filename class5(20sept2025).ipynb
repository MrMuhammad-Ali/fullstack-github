# %%
#F-string

# %%
fname = input('Enter your first name: ')
lname = input('Enter your lname name: ')
course = input('Enter your course name: ')
email = input('Enter your email: ')
print(f'I am {fname} {lname} wants to enroll in this course {course} my email address is {email}')
# Out:
# I am Muhammad Ali wants to enroll in this course Python my email address is Muhammadali@gmail.com

# %%
fname = 'chahat'

# %%
# String's Method

# %%
name = 'chahat fateh ali khan'

# %%
# Methods are those functions that belong to a certain class

# %%
upper_name = name.upper()

# %%
print(upper_name)
print(name)
# Out:
# CHAHAT FATEH ALI KHAN
# chahat fateh ali khan

# %%
print(name)
# Out:
# chahat fateh ali khan

# %%
#Immutable Data Type
