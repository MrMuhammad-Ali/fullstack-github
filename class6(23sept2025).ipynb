# %%
info = 'This is a sentence'

# %%
info
# Out:
# 'This is a sentence'

# %%
type(info)
# Out:
# str

# %%
number = 10

# %%
number.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 number.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
info = info.upper()

# %%
info
# Out:
# 'THIS IS A SENTENCE'

# %%
info.lower()
# Out:
# 'this is a sentence'

# %%
info.title()
# Out:
# 'This Is A Sentence'

# %%
info
# Out:
# 'THIS IS A SENTENCE'

# %%
info.capitalize()
# Out:
# 'This is a sentence'

# %%
fullname = input('This is full name: ').title()

# %%
fullname
# Out:
# 'Muhammad Ali'

# %%
fullname.isupper()
# Out:
# False

# %%
fullname.islower()
# Out:
# False

# %%
fullname.istitle()
# Out:
# True

# %%
empty_string = ''
space_string = ' ' #having space

# %%
fullname
# Out:
# 'Muhammad Ali'

# %%
fullname.isspace()
# Out:
# False

# %%
empty_string.isspace()
# Out:
# False

# %%
space_string.isspace()
# Out:
# True

# %%
'pakistan'
'p a k i s t a n'
# Out:
# 'p a k i s t a n'

# %%
'My name is Muhammad Ali 2112'
# Out:
# 'My name is Muhammad Ali 2112'

# %%
fullname
# Out:
# 'Muhammad Ali'

# %%
fullname.startswith('M')
# Out:
# True

# %%
char = input('Enter the letter? ').upper()
fullname.startswith(char)
# Out:
# True

# %%
fullname.startswith('k')
# Out:
# False

# %%
fullname.endswith('i')
# Out:
# True

# %%
fullname.endswith('a')
# Out:
# False

# %%
fullname.endswith('I'.lower())
# Out:
# True
