# %%
cites = ['karachi', 'Lahore', 'Quetta', 'Murre', 'Larkana']

# %%
#.append ye list main add karta hai kese object ko
cites.append('Multan')

# %%
cites
# Out:
# ['karachi', 'Lahore', 'Quetta', 'Murre', 'Larkana', 'Multan']

# %%
 cites.insert(2, 'sawat')

# %%
cites
# Out:
# ['karachi', 'Lahore', 'sawat', 'sawat', 'Quetta', 'Murre', 'Larkana', 'Multan']

# %%
new_cites = ['Naran', 'Kaghan']

# %%
cites.append(new_cites)

# %%
cites
# Out:
# ['karachi',
#  'Lahore',
#  'sawat',
#  'sawat',
#  'Quetta',
#  'Murre',
#  'Larkana',
#  'Multan',
#  ['Naran', 'Kaghan'],
#  ['Naran', 'Kaghan']]

# %%
cites.insert(0, new_cites)

# %%
cites
# Out:
# [['Naran', 'Kaghan'],
#  ['Naran', 'Kaghan'],
#  'karachi',
#  'Lahore',
#  'sawat',
#  'sawat',
#  'Quetta',
#  'Murre',
#  'Larkana',
#  'Multan',
#  ['Naran', 'Kaghan'],
#  ['Naran', 'Kaghan']]

# %%
print(cites)
print(new_cites)
# Out:
# [['Naran', 'Kaghan'], ['Naran', 'Kaghan'], 'karachi', 'Lahore', 'sawat', 'sawat', 'Quetta', 'Murre', 'Larkana', 'Multan', ['Naran', 'Kaghan'], ['Naran', 'Kaghan']]
# ['Naran', 'Kaghan']

# %%
fav_cites = ['Islamabad', 'Thatta']

# %%
print(new_cites)
print(fav_cites)
# Out:
# ['Naran', 'Kaghan']
# ['Islamabad', 'Thatta']

# %%
combined_cites = new_cites + fav_cites

# %%
combined_cites
# Out:
# ['Naran', 'Kaghan', 'Islamabad', 'Thatta']

# %%
fav_cites.extend(new_cites)

# %%
fav_cites
# Out:
# ['Islamabad', 'Thatta', 'Naran', 'Kaghan', 'Naran', 'Kaghan']

# %%
fruits = ['apple', 'mango', 'kiwi', 'peach']
fav_fruits = ['Banana', 'Orange']

# %%
fruits
fav_fruits
# Out:
# ['Banana', 'Orange']

# %%
all_fruits = fruits + fav_fruits

# %%
all_fruits
# Out:
# ['apple', 'mango', 'kiwi', 'peach', 'Banana', 'Orange']

# %%
len(all_fruits)
# Out:
# 6

# %%
all_fruits[2]
# Out:
# 'kiwi'

# %%
all_fruits.index('kiwi')
# Out:
# 4

# %%
all_fruits
# Out:
# ['apple', 'mango', 'grapes', 'grapes', 'kiwi', 'peach', 'Banana', 'Orange']

# %%
index = all_fruits.index('kiwi')

# %%
all_fruits.insert(index, 'grapes')

# %%
all_fruits
# Out:
# ['apple',
#  'mango',
#  'grapes',
#  'grapes',
#  'grapes',
#  'kiwi',
#  'peach',
#  'Banana',
#  'Orange']

# %%
all_fruits.index('kiwi', 0, 6)
# Out:
# 5

# %%
all_fruits.remove('grapes')

# %%
all_fruits
# Out:
# ['apple', 'mango', 'grapes', 'kiwi', 'peach', 'Banana', 'Orange']

# %%
all_fruits.remove('grapes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 all_fruits.remove('grapes')
#
# ValueError: list.remove(x): x not in list

# %%
all_fruits
# Out:
# ['apple', 'mango', 'kiwi', 'peach', 'Banana', 'Orange']

# %%
all_fruits.append('grapes')

# %%
all_fruits.insert(3, 'grapes')

# %%
all_fruits.remove('grapes')

# %%
all_fruits.append('apple')

# %%
all_fruits
# Out:
# ['kiwi',
#  'peach',
#  'Banana',
#  'Orange',
#  'grapes',
#  'a[pple]',
#  'a[pple',
#  'a[pple',
#  'apple',
#  'apple']

# %%
all_fruits.append('mango')

# %%
all_fruits
# Out:
# ['kiwi',
#  'peach',
#  'Banana',
#  'Orange',
#  'grapes',
#  'a[pple]',
#  'a[pple',
#  'a[pple',
#  'apple',
#  'apple',
#  'mango']

# %%
remove_fruit = all_fruits.remove('mango')

# %%
pop_fruit = all_fruits.pop()

# %%
print(pop_fruit)
print(all_fruits)
# Out:
# apple
# ['kiwi', 'peach', 'Banana', 'Orange', 'grapes', 'a[pple]', 'a[pple', 'a[pple']

# %%
del all_fruits[1]

# %%
all_fruits
# Out:
# ['apple', 'mango', 'kiwi', 'peach', 'Banana', 'Orange']

# %%
banana = del all_fruits[1]
# Out:
#   Cell In[132], line 1
#     banana = del all_fruits[1]
#              ^
# SyntaxError: invalid syntax

# %%
del all_fruits

# %%
all_fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 all_fruits
#
# NameError: name 'all_fruits' is not defined
