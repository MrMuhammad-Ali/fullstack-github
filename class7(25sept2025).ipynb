# %%
fname = input('Enter first name: ').strip()
lname = input('Enter last name: ').strip()
print(f'My first name is {fname} and my last name is {lname}')
# Out:
# My first name is Ali and my last name is Abro

# %%
#.strip bech main jo bhe spasce hoga wo remove kary ga
country = '    Pakistan    '
country.strip()
# Out:
# 'Pakistan'

# %%
#lstrip left side k gape ko khatam kary ga or
#rstrip right side waly gape ko khatam kary ga 
print(country.lstrip())
print(country.rstrip())
# Out:
# Pakistan
#     Pakistan

# %%
info = 'My name is muhammad ali and i live in karachi'

# %%
info
# Out:
# 'My name is muhammad ali and i live in karachi'

# %%
#.replace kese bhe word ko replace karny k leye kam ata hai
info.replace('karachi', 'Larkana')
# Out:
# 'My name is muhammad ali and i live in Larkana'

# %%
info = info.replace('Larkana','Karachi').replace('muhammad ali', 'Ali Abro')

# %%
info
# Out:
# 'My name is Ali Abro and i live in karachi'

# %%
#.find hamed dhund ny main madad karta hai 
#.rfind ye hamen right side say find karta hai
#.index bhe hamen dhund ny main madad karta hai 
#.rindex hamen right say dhund ny main madad karta hai
info.find('karachi')
info.rfind('karachi')
info.index('karachi')
info.rindex('karachi')
# Out:
# 34

# %%
#-1 matlab kjo ham dhund rhy hain wo isy nhe mla. 
info.find('Lahore')
# Out:
# -1

# %%
info = 'my name is muhammad ali i live in Lahore and Lahore is a beautiful city and i dont wnt to leave Lahore'

# %%
info
# Out:
# 'my name is muhammad ali i live in Lahore and Lahore is a beautiful city and i dont wnt to leave Lahore'

# %%
start = info.find('i live')

# %%
end = info.find('city')+ len('city') -1

# %%
info.find('Lahore',start, end)
# Out:
# 34

# %%
info
# Out:
# 'my name is muhammad ali i live in Lahore and Lahore is a beautiful city and i dont wnt to leave Lahore'

# %%
info.find('city')
# Out:
# 67
