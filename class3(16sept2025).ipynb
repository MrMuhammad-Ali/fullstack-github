# %%
print(2+2)
print(2+4)
print(2+2+2+4)
# Out:
# 4
# 6
# 10

# %%
# Variables
# Container to store some value

# %%
num1 = 2 + 2
num2 = 5 + 6
result = num1 + num2
print (num1)
print(num2)
print(result)
# Out:
# 4
# 11
# 15

# %%
# A value 'Ali' is assigned to a variable fname = is a assignment operator
fname = 'Muhammad'
lname = 'Ali'
print(fname, lname)
# Out:
# Muhammad Ali

# %%
fname = 'ali'
lname = 'abro'
print(fname, lname)
# Out:
# ali abro

# %%
print(type(fname))
print(type(lname))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(id(fname))
print(id(lname))
# Out:
# 1454720085104
# 1454720051328

# %%
print(fname)
# Out:
# ali

# %%
print('fname')
# Out:
# fname

# %%
fname
# Out:
# 'ali'

# %%
fname = 'abro'

# %%
fname
# Out:
# 'abro'

# %%
id(fname)
# Out:
# 1454720051328

# %%
fname = 'ali'
lname = 'ali'
print(fname, lname)
# Out:
# ali ali

# %%
print(id(fname))
print(id(lname))
# Out:
# 1454720085104
# 1454720085104
