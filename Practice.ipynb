# %%
print('Muhammad Ali')
# Out:
# Muhammad Ali

# %%
print('Muhammad \nAli \nAbro')
# Out:
# Muhammad
# Ali
# Abro

# %%
print(2+4)
# Out:
# 6

# %%
count = (2+4)

# %%
print(type(count))
# Out:
# <class 'int'>

# %%
type(count)
# Out:
# int

# %%
string = ('Muhammad Ali')

# %%
print(type(string))
# Out:
# <class 'str'>

# %%
type(string)
# Out:
# str

# %%
num = 2+2

# %%
num
# Out:
# 4

# %%
num1 = 5+2
num2 = 2+8
result = (num1+num2)
print(result)
# Out:
# 17

# %%
type(result)
# Out:
# int

# %%
fname = 'Ali'
lname = 'abro'

# %%
fname lname
# Out:
#   Cell In[33], line 1
#     fname lname
#           ^
# SyntaxError: invalid syntax

# %%
(fname, lname)
# Out:
# ('Ali', 'abro')

# %%
print(fname, lname)
# Out:
# Ali abro

# %%
type(fname)
type(lname)
# Out:
# str

# %%
type(num1)
type(fname)
# Out:
# str

# %%
print(type(fname))
print(type(lname))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(type(num1))
print(type(lname))
# Out:
# <class 'int'>
# <class 'str'>

# %%
fname
# Out:
# 'Ali'

# %%
fname = 'khan'

# %%
fname
# Out:
# 'khan'

# %%
print(id(fname))
# Out:
# 1770045310464

# %%
print('Foam')
value = input('Enter your first name')
Value2 = input('Enter yout Last Name')
Value3 = input('Enter your Email')
value4 = int(input('enter your Number'))
# Out:
# Foam

# %%
print('My deta foam')
print(value, Value2, Value3, value4)
# Out:
# My deta foam
# Muhammad Ali Ali@123 123456

# %%
num = 'Ali'

# %%
num = (25.1)
type(num)
# Out:
# float

# %%
print('''Twinkle, twinkle, little star, how I wonder what you are. Up above the world so high,
like a diamond in the sky. Twinkle, twinkle, little star, how I wonder what you are.
When the blazing sun is set, and the grass with dew is wet. Then you show your little
light, twinkle, twinkle all the night. Twinkle, twinkle little star, how I wonder what you
are.
Then the traveler in the dark thanks you for your tiny spark. How could he see where to
go if you did not twinkle so? Twinkle, twinkle little star, how I wonder what you are.
As your bright and tiny spark lights the traveler in the dark, though I know not what you
are, twinkle, twinkle, little star. Twinkle, twinkle, little star, how I wonder what you are. ''')
# Out:
# Twinkle, twinkle, little star, how I wonder what you are. Up above the world so high,
# like a diamond in the sky. Twinkle, twinkle, little star, how I wonder what you are.
# When the blazing sun is set, and the grass with dew is wet. Then you show your little
# light, twinkle, twinkle all the night. Twinkle, twinkle little star, how I wonder what you
# are.
# Then the traveler in the dark thanks you for your tiny spark. How could he see where to
# go if you did not twinkle so? Twinkle, twinkle little star, how I wonder what you are.
# As your bright and tiny spark lights the traveler in the dark, though I know not what you
# are, twinkle, twinkle, little star. Twinkle, twinkle, little star, how I wonder what you are.
