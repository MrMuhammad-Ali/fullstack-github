# %% [markdown]
# ## Tuple

# %%
cites = ('karachi', 'lahore', 'Murre')

# %%
cites
# Out:
# ('karachi', 'lahore', 'Murre')

# %%
type(cites)
# Out:
# tuple

# %%
len(cites)
# Out:
# 3

# %%
print(cites.count('karachi'))
print(cites.index('karachi'))
# Out:
# 1
# 0

# %%
cites[1]
# Out:
# 'lahore'

# %%
cites[1] = Ali khan
# Out:
#   Cell In[7], line 1
#     cites[1] = Ali khan
#                    ^
# SyntaxError: invalid syntax

# %%
del cites[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del cites[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ## Sets

# %%
# A set is a collection of well defined and unique object

# %%
cites = {}
type(cites)
# Out:
# dict

# %%
fruits = set() #empty set

# %%
fruits
# Out:
# set()

# %%
type(fruits)
# Out:
# set

# %%
fruits.add('orange')

# %%
fruits.add('peach', 'mango')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fruits.add('peach', 'mango')
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
fruits.update(('peach', 'mango'))

# %%
fruits
# Out:
# {'mango', 'orange', 'peach'}

# %%
type(fruits)
# Out:
# set

# %%
fruits.update(['banana', 'apple'])

# %%
fruits.update({'mango', 'kiwi'})

# %%
fruits
# Out:
# {'apple', 'banana', 'kiwi', 'mango', 'orange', 'peach'}

# %%
sports = {'cricket'}

# %%
type(sports)
# Out:
# set

# %%
empty_set = set()

# %%
empty_set
# Out:
# set()

# %%
len(empty_set)
# Out:
# 0

# %%
#            Mutable:
# List       ===>   [value1, value2]
# dictionary ===>   {key:value}
# set        ===>   {value1,value2}
#            Immutable
# Tuple      ===>   (value1,value2)

# %% [markdown]
# # Conditions

# %%
age = float(input('Enter your age: '))
years = 18 - age
if age >= 18:
    print('Yes you are eligible for applying for cnic')
# Out:
# Yes you are eligible for applying for cnic

# %%
age = float(input('Enter your age: '))
years = 18 - age
if age >= 18:
    print('Yes you are eligible for applying for cnic')
else:
    print(f'No, wait for {years} years')
# Out:
# Yes you are eligible for applying for cnic

# %%
age = float(input('Enter your age: '))
nationality = input('Enter your nationality: ').title
if age >= 18 and nationality == 'pakistan':
    print('Yes you are eligible for applying for cnic')
else:
    print(f'No, You are not eligible')
# Out:
# No, You are not eligible

# %%
age = float(input('Enter your age: '))
nationality = input('Enter your nationality: ')
if all((age >= 18 ,nationality == 'pakistan')):
    print('Yes you are eligible for applying for cnic')
else:
    print(f'No, You are not eligible')
# Out:
# Yes you are eligible for applying for cnic

# %%
payment_method = input('Enter paymentmethod').title()
if payment_method == 'Easy Paisa' or payment_method == 'Cash':
    print('Your order has been placed succefully')
else:
    print('Change your payment method')
# Out:
# Change your payment method

# %%
cities = ('Karachi', 'lahore')

# %%
'Karachi' in cities
# Out:
# True

# %%
payment_method = input('Enter payment method')
if payment_method in ('cash', 'Easy paisa', 'Bank'):
    print('Your order has been placed succefully')
else:
    print('Change your payment method')
# Out:
# Your order has been placed succefully

# %%
# all((True, True) )

# %%
payment_method = input('Enter payment method').title()
address = input('Enter your address')
if payment_method in ('Cash', 'Easy paisa', 'Bank') and address:
    print('Your order has been placed succefully')
else:
    print('No you can not')
# Out:
# No you can not

# %%
address = '1'
bool(address)
# Out:
# True
